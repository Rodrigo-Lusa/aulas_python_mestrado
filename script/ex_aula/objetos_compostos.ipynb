# %%
obj_tupla = (1, 3, 3)
obj_tupla
# Out:
# (1, 3, 3)

# %%
#obj_list = [-3,             -2,         -1]
#obj_list = [0,               1,          2]
obj_lista = ["penguim", "coala", "preguiça"]
obj_lista
# Out:
# ['penguim', 'coala', 'preguiça']

# %%
# Usando string como chave
obj_dict = {"gene_1": "ATCGTG",
            "gene_2": "ATGATGATAGT",
            "gene_tal": "ATGTAGTAG"}
obj_dict["gene_tal"]
# Out:
# 'ATGTAGTAG'

# %%
# Usando int como chave
dict2 = {1: "a", 2: "b"}
dict2[1]
# Out:
# 'a'

# %%
# Adicionar item no dicionário
dict2[3] = "c"

# Ver o tipo
type(dict2[3])
# Out:
# str

# %%
obj_set = {1, 2, 3}
obj_set
# Out:
# {1, 2, 3}

# %%
print(f"{obj_tupla}: {type(obj_tupla)}")
print(f"{obj_lista}: {type(obj_lista)}")
print(f"{obj_dict}: {type(obj_dict)}")
print(f"{obj_set}: {type(obj_set)}")
# Out:
# (1, 3, 3): <class 'tuple'>
# ['penguim', 'coala', 'preguiça']: <class 'list'>
# {'gene_1': 'ATCGTG', 'gene_2': 'ATGATGATAGT', 'gene_tal': 'ATGTAGTAG'}: <class 'dict'>
# {1, 2, 3}: <class 'set'>

# %%
display("ATG" in obj_dict["gene_tal"])

obj_lista.append("formiga")
print(obj_lista)
# Out:
# True
# ['penguim', 'coala', 'preguiça', 'formiga', 'formiga', 'formiga', 'formiga']
# formiga

# %%
display(obj_dict)

obj_dict["Qualquer"] = "Abacaxi"
display(obj_dict)
# Out:
# {'gene_1': 'ATCGTG', 'gene_2': 'ATGATGATAGT', 'gene_tal': 'ATGTAGTAG'}
# {'gene_1': 'ATCGTG',
#  'gene_2': 'ATGATGATAGT',
#  'gene_tal': 'ATGTAGTAG',
#  'Qualquer': 'Abacaxi'}

# %%
#obj_lista.pop() -> deleta o último
obj_lista = ['penguim', 'coala', 'preguiça', 'formiga']
print(obj_lista)

num = obj_lista.pop()

print(f"Retirou '{num}', sobrou {obj_lista}")
# Out:
# ['penguim', 'coala', 'preguiça', 'formiga']
# Retirou 'formiga', sobrou ['penguim', 'coala', 'preguiça']
