# %%
import pandas as pd
import numpy as np

# %%
simbolo = [
    'IFNG',
    'Il10',
    'Tnf',
    'CSF2'
]

full_name = [
    'interferon gamma',
    'interleuckin 10',
    'tumor necrosis factor',
    'colony stimulation factor 2'
]

source = [
    'HGNC:HGNC:5438',
    'RGD:2886',
    'MGI:MGI:104798',
    'HGNC:HGNC:2434'
]

gene_type = [
    'protein coding',
    'protein coding',
    'protein coding',
    'protein coding',
]

organism = [
    'Homo sapiens',
    'Rattus norvegicus',
    'Mus musculus',
    'Homo sapiens'
]

chromosome = [
    12,
    13,
    17,
    5
]

# %%
gene_matriz_lista = [
    simbolo,
    full_name,
    source,
    gene_type,
    organism,
    chromosome
]

# %%
gene_dict = {
    "simbolo": simbolo,
    "full_name": full_name,
    "source": source,
    "gene_type": gene_type,
    "organism": organism,
    "chromosome": chromosome
}


# Dar append em simbolo, altera símbolo e gene_dict. O mesmo se alterar gene_dict[simbolo], altera a lista original

# %% [markdown]
# # Numpy

# %%
gene_array = np.array(gene_matriz_lista)
gene_array
# Out:
# array([['IFNG', 'Il10', 'Tnf', 'CSF2'],
#        ['interferon gamma', 'interleuckin 10', 'tumor necrosis factor',
#         'colony stimulation factor 2'],
#        ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#        ['protein coding', 'protein coding', 'protein coding',
#         'protein coding'],
#        ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus',
#         'Homo sapiens'],
#        ['12', '13', '17', '5']], dtype='<U27')

# %%
gene_array.shape
# Out:
# (6, 4)

# %%
# Indexar linhas
index = [3,1,4]

gene_array[index]
# Out:
# array([['protein coding', 'protein coding', 'protein coding',
#         'protein coding'],
#        ['interferon gamma', 'interleuckin 10', 'tumor necrosis factor',
#         'colony stimulation factor 2'],
#        ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus',
#         'Homo sapiens']], dtype='<U27')

# %%
# Indexar colunas
#    array[todas as linhas, coluna 0]
gene_array[:, 0]
# Out:
# array(['IFNG', 'interferon gamma', 'HGNC:HGNC:5438', 'protein coding',
#        'Homo sapiens', '12'], dtype='<U27')

# %%
gene_array[:, [1,3]]
# Out:
# array([['Il10', 'CSF2'],
#        ['interleuckin 10', 'colony stimulation factor 2'],
#        ['RGD:2886', 'HGNC:HGNC:2434'],
#        ['protein coding', 'protein coding'],
#        ['Rattus norvegicus', 'Homo sapiens'],
#        ['13', '5']], dtype='<U27')

# %%
gene_array[-1, 1:3]
# Out:
# array(['13', '17'], dtype='<U27')
