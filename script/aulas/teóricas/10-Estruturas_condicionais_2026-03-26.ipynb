# %%
# Verificando se a lâmpada está queimada ou não
bocal = "queimado"
if bocal == "queimado":
    print("Substitua o bocal!")
else:
    print("Compre uma nova lâmpada!")
# Out:
# Substitua o bocal!

# %%
# Usando operador relacional para verificar se o bocal está queimado
bocal == "queimado"
# Out:
# True

# %%
# Instanciando a variável bocal com um valor diferente
bocal = "funcionando"

# %%
# Verificando novamente se o bocal está queimado
bocal == "queimado"
# Out:
# False

# %%
print("Substitua o bocal!")
# Out:
# Substitua o bocal!

# %%
print("Compre uma nova lâmpada!")
# Out:
# Compre uma nova lâmpada!

# %%
# Verificando se a lâmpada está queimada ou não

if bocal == "queimado" or bocal == "funcionandno":
    print(f"Bocal testado e {bocal}!")
else:
    print("Bocal não testado!")
# Out:
# Bocal não testado!
