# %% [markdown]
# # Algoritmo

# %%
# Verifica se a lâmpada está ligada e se o bocal está queimado para determinar a ação necessária.
lampada = "ligada"
bocal = "queimado"

if lampada == "ligada":
    if bocal == "queimado":
        print("Subistitua o bocal!")
    else:
        print("Compre uma nova lâmpada!")
else:
    print("Ligue a lâmpada!")
# Out:
# Subistitua o bocal!
